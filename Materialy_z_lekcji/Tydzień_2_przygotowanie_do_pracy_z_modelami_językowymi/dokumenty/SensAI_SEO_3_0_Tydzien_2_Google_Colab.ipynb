# %% [markdown]
# ---
#
#
# | | |
# |---|---|
# | **Autor notatnika** | Damian Sałkowski |
# | **Wersja** | 1.0 |
# | **Wydawca** | [sensai.academy](https://sensai.academy/) |
# | **Lekcja** | Google Colab |
# | **Tydzień programu** | 2 |
# | **Pytania? Napisz na discord. 📩 ** | **damian_17365** |
#
#
# ---
#
# # Witaj w Świecie SEO 3.0 z Google Colab! | Kurs SensAI
#
# Witaj na pokładzie kursu SEO 3.0 od SensAI! W tej części wprowadzimy Cię w świat Google Colaboratory (Colab) – narzędzia, które stanie się Twoim niezastąpionym sprzymierzeńcem w automatyzacji zadań, analizie danych na dużą skalę i wykorzystaniu potencjału AI w SEO.
#
# **Dlaczego Colab w SEO 3.0?**
# W erze SEO 3.0 nie wystarczy już tylko "czucie". Potrzebujemy danych, automatyzacji i inteligentnych narzędzi. Colab oferuje:
# *   **Darmową Moc Obliczeniową:** Dostęp do zasobów (GPU!), które pozwolą analizować ogromne ilości danych (np. logi serwera, dane z GSC, wyniki crawlów) bez obciążania Twojego komputera.
# *   **Automatyzację:** Tworzenie skryptów w Pythonie do powtarzalnych zadań (np. sprawdzanie statusów stron, monitoring zmian, proste audyty).
# *   **Integrację:** Łatwe łączenie z API (np. Google Search Console API, narzędzia SEO) i Twoim Dyskiem Google.
# *   **Współpracę:** Dzielenie się analizami i skryptami z zespołem lub klientami.
# *   **Wrota do AI:** Idealne środowisko do eksperymentowania z modelami językowymi (np. do generowania meta opisów, analizy sentymentu) i uczeniem maszynowym w SEO.
#
# **Jak korzystać z tego notatnika?**
# Czytaj opisy i uruchamiaj kolejne komórki kodu, aby interaktywnie poznać podstawy Colab. Zaczynajmy rewolucjonizować Twoje SEO z SensAI!

# %% [markdown]
# ## Komórki Tekstowe vs Komórki Kodu w Pracy SEO
#
# Notatniki Colab składają się z dwóch typów komórek, które będziemy wykorzystywać w naszej pracy SEO:
#
# 1.  **Komórki Tekstowe:** Jak ta. Służą do dokumentowania procesu, wyjaśniania strategii, opisywania wyników analizy, wklejania notatek czy instrukcji. Używają formatowania **Markdown**.
# 2.  **Komórki Kodu:** Tutaj dzieje się magia! Zawierają kod Python, który wykonuje konkretne zadania: pobiera dane z API, czyści adresy URL, analizuje słowa kluczowe, wizualizuje dane, automatyzuje raportowanie itp.
#
# Kliknij dwukrotnie komórkę tekstową, aby ją edytować. Kliknij poza nią lub użyj `Shift+Enter`, aby zobaczyć sformatowany tekst.

# %%
# Pierwszy krok w automatyzacji SEO z Colab!
# Uruchom tę komórkę, aby zobaczyć komunikat poniżej.

print("Automatyzacja i analiza danych to klucz do SEO 3.0 z SensAI!")

# --- Jak uruchomić tę komórkę? ---
# 1. Kliknij ikonę "play" (trójkąt) po lewej stronie.
# LUB
# 2. Zaznacz komórkę (kliknij ją) i naciśnij Shift + Enter.

# Spróbuj! Zobaczysz, jak Colab wykonuje Twój pierwszy "skrypt".
# Out:
# Automatyzacja i analiza danych to klucz do SEO 3.0 z SensAI!

# %% [markdown]
# Świetnie! Widzisz tekst pod poprzednią komórką? To wynik działania Twojego kodu.
#
# ## Zmienne: Przechowywanie Danych SEO
#
# W Pythonie (i w Colab) używamy **zmiennych** do przechowywania informacji, z którymi pracujemy. Mogą to być słowa kluczowe, adresy URL, wyniki analizy, liczby linków, dane z GSC itp.
#
# Zmienne zdefiniowane w jednej komórce są dostępne w kolejnych (w tej samej sesji). Zobaczmy przykład:

# %%
# Przechowajmy kilka danych SEO w zmiennych
glowne_slowo_kluczowe = "Sztuczna Inteligencja w SEO"
url_artykulu = "https://przykladowa-strona.pl/blog/ai-w-seo"
liczba_backlinkow = 15

# Możemy łatwo manipulować tekstem, np. zamienić na małe litery
slowo_kluczowe_male = glowne_slowo_kluczowe.lower()

print("Analizowane słowo kluczowe:", glowne_slowo_kluczowe)
print("Słowo kluczowe małymi literami:", slowo_kluczowe_male)
print("URL artykułu:", url_artykulu)
print("Liczba linków zwrotnych:", liczba_backlinkow)

# Uruchom tę komórkę (Shift + Enter)
# Out:
# Analizowane słowo kluczowe: Sztuczna Inteligencja w SEO
# Słowo kluczowe małymi literami: sztuczna inteligencja w seo
# URL artykułu: https://przykladowa-strona.pl/blog/ai-w-seo
# Liczba linków zwrotnych: 15

# %%
# Colab pamięta zmienne z poprzedniej komórki!
print("Przypomnienie: Pracujemy nad słowem kluczowym:", glowne_slowo_kluczowe)

# Możemy tworzyć proste raporty lub komunikaty
komunikat = f"Artykuł '{url_artykulu}' ma {liczba_backlinkow} linków dla frazy '{glowne_slowo_kluczowe}'."
print("\n--- Prosty Raport ---")
print(komunikat)
# Out:
# Przypomnienie: Pracujemy nad słowem kluczowym: Sztuczna Inteligencja w SEO
#
# --- Prosty Raport ---
# Artykuł 'https://przykladowa-strona.pl/blog/ai-w-seo' ma 15 linków dla frazy 'Sztuczna Inteligencja w SEO'.

# %% [markdown]
# ## Formatowanie Tekstu (Markdown) w Dokumentacji SEO
#
# Markdown jest świetny do tworzenia przejrzystych notatek, raportów i dokumentacji Twoich działań SEO bezpośrednio w Colab. Oto przykłady (kliknij dwukrotnie, aby zobaczyć kod):
#
# # Raport SEO: Analiza Słów Kluczowych
#
# ## Główne Słowa Kluczowe
# *   **Słowo 1:** Wysoki potencjał, niska konkurencja.
# *   *Słowo 2:* Średni potencjał, wysoka konkurencja (wymaga optymalizacji).
#
# ## Zalecenia
# 1.  Optymalizacja treści pod **Słowo 1**.
# 2.  Budowa linków dla strony docelowej *Słowa 2*.
#
# ### Przykładowy fragment kodu API (tylko jako tekst)
# ```python
# response = service.searchanalytics().query(siteUrl=site_url, body=request).execute()

# %% [markdown]
# ## Ćwiczenie: Twoja Notatka SEO
#
# Teraz Twoja kolej:
# 1.  Najedź myszką tuż pod tę komórkę i kliknij `+ Tekst`.
# 2.  W nowej komórce stwórz krótką notatkę dotyczącą fikcyjnego zadania SEO, używając Markdown:
#     *   Nagłówek (np. `## Audyt On-Page dla Strony X`).
#     *   Listę punktowaną z 2-3 elementami do sprawdzenia (np. `* Sprawdzenie tytułów`, `* Analiza meta opisów`).
#     *   Jedno słowo **pogrubione** i jedno *kursywą*.

# %% [markdown]
# ## Ułatwienie Pracy: Interaktywne Formularze w Colab
#
# Jedną z bardzo przydatnych funkcji Colab, szczególnie gdy chcesz udostępnić notatnik innym (np. w zespole SensAI lub klientowi) lub po prostu ułatwić sobie rekonfigurację skryptu, są **interaktywne formularze**.
#
# Pozwalają one na tworzenie prostych pól (tekstowych, liczbowych, list rozwijanych, checkboxów), które **automatycznie stają się zmiennymi Pythona** w danej komórce kodu. Dzięki temu można zmieniać parametry skryptu (np. analizowane słowo kluczowe, datę, próg liczbowy) bez dotykania samego kodu!
#
# Formularze tworzy się za pomocą specjalnego komentarza `#@param` na początku komórki kodu. Zobaczmy jak działają poszczególne typy.
#
# **Ważne:** Pola formularza pojawią się automatycznie nad kodem w komórce, gdy tylko dodasz komentarz `#@param`. Możesz też zarządzać widocznością formularzy globalnie (Menu: Narzędzia -> Ustawienia -> Formularze).

# %%
#@title Pole Input
#@markdown ---
#@markdown Wpisz poniżej główne słowo kluczowe, które chcesz analizować w tym (hipotetycznym) skrypcie:
slowo_kluczowe_do_analizy = "seo sensai" #@param {type:"string"}


print(f"Rozpoczynam analizę dla słowa kluczowego: '{slowo_kluczowe_do_analizy}'")
# Out:
# Rozpoczynam analizę dla słowa kluczowego: 'wpisz słowo kluczowe tutaj'

# %%
#@title Pole Input liczbowe i slidery
minimalny_wolumen_wyszukiwan = 300 #@param {type:"integer", min:0, max:10000, step:50}
#@markdown Minimalna średnia miesięczna liczba wyszukiwań słowa kluczowego, aby je uwzględnić.

maksymalna_liczba_wynikow = 85 #@param {type:"slider", min:10, max:100, step:5}
#@markdown Ile maksymalnie wyników z SERP pobrać do analizy?

#@markdown ---

print(f"Minimalny wymagany wolumen wyszukiwań: {minimalny_wolumen_wyszukiwan}")
print(f"Maksymalna liczba analizowanych wyników: {maksymalna_liczba_wynikow}")

# %%
#@title Formularze dropdown
@title Wybierz Rynek i Język
@param rynek_docelowy = "Wielka Brytania" #@param ["Polska", "Niemcy", "Wielka Brytania", "USA", "Globalny"]
#@markdown Wybierz główny rynek docelowy dla tej analizy.

@param jezyk_analizy = "de" #@param ["pl", "en", "de", "es"]
@markdown Wybierz kod języka (np. do API lub filtrów).

#@markdown ---

print(f"Analiza będzie przeprowadzona dla rynku: {rynek_docelowy}")
print(f"Używany język: {jezyk_analizy}")

# %%
#@title Checkboxy
#@title Opcje Dodatkowe Analizy
uwzglednij_frazy_brandowe = True #@param {type:"boolean"}
#@markdown Zaznacz, jeśli chcesz uwzględnić w analizie również frazy zawierające nazwę marki.


zapisz_wyniki_na_dysku = True #@param {type:"boolean"}
#@markdown Zaznacz, aby zapisać końcowy raport na Twoim Dysku Google (wymaga zamontowanego Dysku!).

#@markdown ---

print(f"Czy uwzględniać frazy brandowe? {'Tak' if uwzglednij_frazy_brandowe else 'Nie'}")
print(f"Czy zapisać wyniki na Dysku? {'Tak' if zapisz_wyniki_na_dysku else 'Nie'}")

if zapisz_wyniki_na_dysku:
  print("-> Wybrano opcję zapisu wyników (w realnym skrypcie tutaj byłby kod zapisujący plik).")
else:
  print("-> Wyniki nie będą zapisywane na Dysku.")
# Out:
# Czy uwzględniać frazy brandowe? Tak
# Czy zapisać wyniki na Dysku? Tak
# -> Wybrano opcję zapisu wyników (w realnym skrypcie tutaj byłby kod zapisujący plik).

# %%
#@title Kalendarze
@param data_poczatkowa = "2023-01-12" #@param {type:"date"}
#@markdown Wybierz datę początkową okresu analizy.

@param data_koncowa = "2023-12-21" #@param {type:"date"}
#@markdown Wybierz datę końcową okresu analizy.

#@markdown ---

print(f"Analiza obejmie okres od {data_poczatkowa} do {data_koncowa}")

# %% [markdown]
# ## Niezbędne Narzędzia: Importowanie Bibliotek Python dla SEO
#
# Siła Pythona i Colab w SEO tkwi w bibliotekach - gotowych zestawach narzędzi do konkretnych zadań. Wiele z nich jest już w Colab, inne będziemy instalować. Kluczowe dla nas będą m.in.:
# *   `pandas`: Do pracy z danymi tabelarycznymi (listy słów kluczowych, dane z GSC, wyniki crawlów).
# *   `requests`: Do pobierania zawartości stron internetowych (podstawa scrapingu i sprawdzania statusów).
# *   `BeautifulSoup`: Do "czytania" i wyciągania informacji ze stron HTML (np. tytułów, nagłówków, linków).
# *   `matplotlib` / `seaborn`: Do tworzenia wykresów i wizualizacji danych SEO.
# *   (W przyszłości) `nltk`, `spaCy`, `scikit-learn`: Do zaawansowanej analizy tekstu (NLP) i budowy modeli AI dla SEO.
#
# Importujemy je standardowo za pomocą `import`:

# %%
import pandas as pd # Importujemy bibliotekę pandas i nadajemy jej skrót 'pd'

# Stwórzmy prostą tabelę z danymi słów kluczowych
dane_seo = {
    'Słowo kluczowe': ['seo 3.0', 'kurs ai w seo', 'automatyzacja seo python'],
    'Śr. mies. wyszukania': [500, 150, 70],
    'Trudność (0-100)': [65, 50, 75]
}

df_keywords = pd.DataFrame(dane_seo) # Tworzymy obiekt DataFrame

print("--- Przykładowa Tabela Danych SEO (Pandas DataFrame) ---")
print(df_keywords)

print("\nTyp danych pierwszego słowa kluczowego:", df_keywords['Słowo kluczowe'][0])

# Uruchom tę komórkę. Zobaczysz ładnie sformatowaną tabelę. Pandas to podstawa analizy danych w SEO!
# Out:
# --- Przykładowa Tabela Danych SEO (Pandas DataFrame) ---
#              Słowo kluczowe  Śr. mies. wyszukania  Trudność (0-100)
# 0                   seo 3.0                   500                65
# 1             kurs ai w seo                   150                50
# 2  automatyzacja seo python                    70                75
#
# Typ danych pierwszego słowa kluczowego: seo 3.0

# %% [markdown]
# ## Rozszerzanie Arsenału: Instalowanie Dodatkowych Narzędzi SEO (`pip`)
#
# Czasem będziemy potrzebować bardziej specjalistycznych narzędzi lub bibliotek, których Colab nie ma domyślnie (np. biblioteki do komunikacji z API Ahrefs, Senuto, czy narzędzi do scrapingu). Instalujemy je za pomocą `pip`.
#
# Składnia w komórce kodu: `!pip install nazwa_biblioteki` (pamiętaj o wykrzykniku `!`).
#
# **Ważne:** Instalacja działa tylko dla **bieżącej sesji**. Po restarcie środowiska trzeba będzie instalować ponownie (dlatego często komórki instalacyjne umieszcza się na początku notatnika).
#
# Zainstalujmy teraz dwie fundamentalne biblioteki do pobierania i analizy stron WWW: `requests` i `beautifulsoup4`. Użyjemy opcji `-q` (quiet), aby ograniczyć komunikaty.

# %%
# Instalujemy biblioteki requests (do pobierania stron) i beautifulsoup4 (do parsowania HTML)
# !pip install requests beautifulsoup4 -q

print("Biblioteki requests i beautifulsoup4 gotowe do użycia (w tej sesji).")

# W kolejnych lekcjach kursu SensAI użyjemy ich do praktycznych zadań SEO!
# Na razie wystarczy, że wiesz, jak je zainstalować.

# Uruchom tę komórkę.
# Out:
# Biblioteki requests i beautifulsoup4 gotowe do użycia (w tej sesji).

# %% [markdown]
# ## Silnik Twoich Analiz: Środowisko Wykonawcze (Runtime) i Akceleratory
#
# Twój kod działa na serwerach Google. To **środowisko wykonawcze** pamięta zmienne i zainstalowane biblioteki (tylko w bieżącej sesji!).
#
# Największy "game changer" Colab dla SEO 3.0 to dostęp do **akceleratorów sprzętowych**:
# *   **GPU:** Niezbędne do szybkiego przetwarzania dużych zbiorów danych tekstowych (np. analiza tysięcy opisów produktów, treści konkurencji) za pomocą modeli NLP lub trenowania własnych modeli AI dla SEO.
# *   **TPU:** Jeszcze szybsze, specjalistyczne układy Google, przydatne przy bardzo dużych modelach (głównie TensorFlow).
#
# Jak zmienić? **Menu: Runtime (Środowisko wykonawcze) -> Change runtime type (Zmień typ środowiska wykonawczego) -> Hardware accelerator (Akcelerator sprzętowy)**.
#
# **Pamiętaj:** Zmiana typu środowiska **resetuje sesję** (tracisz zmienne i zainstalowane biblioteki)! Na razie zostajemy przy standardowym CPU.

# %% [markdown]
# ## Twoja Baza Danych SEO: Łączenie z Dyskiem Google
#
# Praca w SEO to praca z plikami: eksporty słów kluczowych z Senuto/Ahrefs, dane z Google Search Console, listy URLi do audytu, wyniki crawlów Screaming Frog, raporty konkurencji... Gdzie je trzymać? Na Dysku Google!
#
# Colab pozwala **zamontować** Twój Dysk Google, dając Ci bezpośredni dostęp do tych plików z poziomu kodu Python. To absolutnie kluczowe dla efektywnej pracy.

# %%
from google.colab import drive # Importujemy moduł do obsługi Dysku

# Uruchomienie tej komórki rozpocznie proces montowania Dysku.
# Będziesz musiał/a autoryzować dostęp Colab do Twoich plików na Dysku Google:
# Postępuj zgodnie z instrukcjami: kliknij link, zaloguj się, skopiuj kod, wklej poniżej.
# To bezpieczny proces autoryzacji Google.

drive.mount('/content/drive')

# Po sukcesie, Twoje pliki z 'Mojego Dysku' będą w folderze /content/drive/My Drive/
# Teraz możesz np. wczytać plik CSV z danymi z GSC!
# Out:
# Mounted at /content/drive

# %% [markdown]
# Super! Jeśli widzisz komunikat "Mounted at /content/drive", Twój Dysk jest podłączony do tej sesji Colab.
#
# Możemy teraz zajrzeć do środka. Użyjmy polecenia systemowego `ls` (list), aby zobaczyć zawartość głównego folderu Twojego Dysku (`My Drive`). Może znajdziesz tam folder z danymi do kursu SensAI? 😉

# %%
# Listujemy zawartość głównego katalogu na Twoim Dysku Google
# Uruchom tę komórkę (zadziała tylko po udanym montowaniu Dysku!)

# !ls "/content/drive/My Drive/"

# Wskazówka: Jeśli masz folder np. "Dane SEO", możesz wylistować jego zawartość:
# !ls "/content/drive/My Drive/Dane SEO/"
# Out:
#  1111111.csv
# '#1 Hackato Senuto - Vextor AI.gdoc'
#  200.gif
#  2023.04.12-EPS-SEO-dla-blogerów-10-Damian-Sałkowski-do-autoryzacji.gdoc
# '2024-11-19 informacji Senuto.pdf'
#  2024-11-30_5671873545.PDF
#  222_oczyszczone.csv
# '2 teksty do porównania .gdoc'
#  aboutdecor_pl_out.csv
# 'Ads & SEO Senuto.gsheet'
#  advertising-adwords-keywords.gsheet
#  Agencje.csv
#  aggregates_distance.csv
#  aggregates_steps.csv
# 'ai_news_classified (1).csv'
#  ai_news_classified_20250212_181022.csv
#  ai_news_classified_20250213_092346.csv
# 'ai_news_classified_20250214_153236 (1).csv'
#  ai_news_deduplicated_20250227_084113.csv
# 'AI Writer - testy'
# 'Akcja stary cennik.gsheet'
# 'Allegro duplikaty.gsheet'
#  allegro_pl_out.csv
# 'Allegro - projekty.gsheet'
# 'Allegro - projekty monitoring.gsheet'
#  amazon_pl_out.csv
# 'Analityka [Senuto] - Poprawki .gdoc'
#  analiza_serp_narz_dzie_top_100_crawler_2024_07_30_09_20.gsheet
#  analiza_serp_narz_dzie_top_100_crawler_2024_07_30_09_20.xlsx
# 'analiza_serp_narz_dzie_url_crawler_2025_02_05_18_38 (1).xlsx'
# 'Analiza Tekstu.gsheet'
#  analiza_widoczno_ci_narz_dzie_analiza_url_2024_02_09_15_50.xlsx
#  analiza_widoczno_ci_raport_adresy_url_leroymerlin_pl_2024_02_09_17_12.xlsx
#  analiza_widoczno_ci_raport_adresy_url_obi_pl_2025_01_12_17_03.xlsx
#  analiza_widoczno_ci_raport__advance_mk_pl_2023_12_11_00_22.gsheet
#  analiza_widoczno_ci_raport__advance_mk_pl_2023_12_11_00_22.xlsx
# 'Analytics www.superwnetrze.pl Ecommerce Overview 20081105-20231111.csv'
# 'Analytics www.superwnetrze.pl Product Performance 20230101-20231111.csv'
# 'Ankieta po spotkaniu z Senuto.gform'
# 'Ankietowanie klientów.gsheet'
# 'Answear blog - linki wewnętrzne.gsheet'
# 'Answear.com - dodatkowy projekt do zrealizowania .gdoc'
#  Answear_final.csv
# 'Answear - linki wewnętrzne blog (part 1.).gsheet'
# 'Answear - próbka (1).gsheet'
# 'Answear - próbka (2).gsheet'
# 'Answear - próbka.gsheet'
# 'Answear - raport.gsheet'
#  Aplikuj_linkowanie_wewnetrzne_master.csv
# 'Aplikuj_linkowanie_wewnetrzne_wyniki (1).csv'
#  Aplikuj.pl
# 'Aplikuj.pl - linki wewnętrzne (v 1.0).gsheet'
# 'Aplikuj.pl - wyniki.gsheet'
# 'Aplikuj.pl - wyniki linkowanie wewnetrzne.gsheet'
#  app-release.apk
# 'ARANŻACJA_PARTER_18122024 (1).pdf'
#  ARANŻACJA_PIĘTRO_18122024.pdf
# 'Archive 2.zip'
# 'Argumentacja dla PARP.gdoc'
# 'Arkusz kalkulacyjny bez nazwy.gsheet'
# 'Arkusz kalkulacyjny bez tytułu (10).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (11).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (12).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (13).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (14).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (15).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (16).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (17).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (18).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (19).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (1).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (20).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (21).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (22).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (23).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (24).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (25).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (26).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (27).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (28).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (29).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (2).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (30).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (31).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (32).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (33).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (34).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (35).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (36).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (37).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (38).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (39).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (3).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (40).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (41).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (42).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (43).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (4).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (5).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (6).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (7).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (8).gsheet'
# 'Arkusz kalkulacyjny bez tytułu (9).gsheet'
# 'Arkusz kalkulacyjny bez tytułu.gsheet'
# 'Artykuły AI WhitePress.gsheet'
# 'Artykuły - Damian'
# 'Audyt AW Senuto .gdoc'
# 'Audyt SEO Sklepu internetowego - zawartość.gdoc'
# 'aw_test_top10 (1) (1).csv'
# 'aw_test_top10 (1) (2).csv'
# 'aw_test_top10 (1) (3).csv'
# 'aw_test_top10 (1) (4).csv'
# 'aw_test_top10 (1).csv'
# 'aw_test_top10 (1).gsheet'
# 'aw_test_top10 (2).csv'
# 'aw_test_top10 (3) (1).csv'
# 'aw_test_top10 (3).csv'
#  aw_test_top10.csv
# 'Back-end crawl.gsheet'
# 'Backlink tracking tool.gsheet'
# 'Badanie OBI.gsheet'
#  Bannery
#  Bartek.jpg
# 'batch_analysis_export.utf-16 (35).csv'
# '[Baza automatyzacji Senuto] Raport zbiorczy wszystkich projektów w Google Data Studio .gsheet'
# 'Baza domen.gsheet'
# 'Baza do Warszawy.gsheet'
# 'Baza raportów Senuto.gsheet'
#  baza_s__w_kluczowych_narz_dzie_statystyki_s__w_2024_02_05_13_03.xlsx
# 'Baza wiedzy o Sensai.gdoc'
# 'Best Articles about SEO & Marketing.gsheet'
# 'BF 2021.gsheet'
# 'BF 2021 vol 2. .gsheet'
# 'blueprint (5).json'
#  b.michalak@senuto.com
#  Bratysława.gslides
# 'brightonSEO title slide.gslides'
#  Brighton_SEO_Video
# 'Brighton with fine-tuning.gslides'
#  Budapest.gslides
# 'Budżet kulturalnie o SEO 2024.gsheet'
# 'Budżet marketingowy 2022.gsheet'
# 'Budżet Senuto 2023 - team template.gsheet'
# 'Budżet SENUTO 2024 - management .gsheet'
# 'categorized_keywords (1).csv'
#  categorized_keywords.csv
#  Certyfikaty.gsheet
# 'Churn bazując na rodzaju płatności.gsheet'
#  churn_raport_2019-03-01.csv
# 'Churn - statystyki AW.gsheet'
# 'Churn wzór RTB .gsheet'
#  _Churn_z_danego_miesica_lista.csv
# 'cleaned_data (1).csv'
#  cleaned_data.csv
#  Cleaned_Kategorie_Corrected.csv
#  Cleaned_Kategorie.csv
#  Cleaned_Kategorie_Final.csv
#  Cleaned_Kategorie_v2.csv
# 'Colab Notebooks'
#  collected_data2.csv
#  collected_data3.csv
#  complete_categorization_with_descriptions.csv
# 'Connections 2.csv'
#  Consolidated_Sales_Data.csv
# 'content-pages (1).gsheet'
#  content-pages.gsheet
# 'Content planner badanie.gsheet'
# '_Content_plany (1).csv'
#  _Content_plany.csv
# 'conversions-ecommerce-overview-beta (1).gsheet'
# 'conversions-ecommerce-overview-beta (2).gsheet'
#  conversions-ecommerce-overview-beta.gsheet
#  conversions-ecommerce-product-performance.gsheet
#  converted_to_utf8_corrected.csv
#  converted_to_utf8.csv
#  COO.gsheet
# 'COO - poszukiwania do Senuto.gsheet'
# 'Copy of Budget SENUTO 2025.gsheet'
# 'Copy of Budżet SENUTO 2024.gsheet'
# 'Copy of Copy of Słupki pionowe.gsheet'
# 'Copy of Copy of Wykres liniowy.gsheet'
# 'Copy of EN Projekt - Ecommerce AI Writer - prezentacja sprzedażowa.gslides'
# 'Copy of gemma-3-finetune.Q8_0.gguf'
# 'Copy of Long -Projekt - Ecommerce AI Writer - prezentacja sprzedażowa.gslides'
# 'Copy of Map of Europe Infographics by Slidesgo (1).gslides'
# 'Copy of Map of Europe Infographics by Slidesgo.gslides'
# 'Copy of Oferta Vestigio - Szablon.gslides'
# 'Copy of Remont Zełwągi kosztorys - February 15, 9:36 PM.gsheet'
# "Copy of Senuto BI 2023_🖤 Black Friday '23_Tabela.gsheet"
# 'Copy of Senuto - prezentacja mutlimedialna (1).gslides'
# 'Copy of Senuto - prezentacja mutlimedialna.gslides'
# 'Copy of SEO_analiza.gsheet'
# 'Copy of Słupki pionowe (1).gsheet'
# 'Copy of Słupki pionowe (2).gsheet'
# 'Copy of Słupki pionowe (3).gsheet'
# 'Copy of Słupki pionowe.gsheet'
# 'Copy of Umowa dla prelegentów - 25. Targi eHandlu Warszawa.gdoc'
# 'Copy of WhitePress_update_2023_06.gslides'
# 'Copy of Wykres kołowy.gsheet'
# 'Copy of Wykres liniowy (1).gsheet'
# 'Copy of Wykres liniowy.gsheet'
#  crawler_google_keywords.txt
# 'crawler_urls_checker_urls_algo (1).csv'
# 'crawler_urls_checker_urls_algo (2).csv'
#  crawler_urls_checker_urls_algo.csv
# 'crawl_senuto (11).csv'
#  D4.Lista_Domen_Senuto.gsheet
# 'D4S test.gsheet'
# 'Damian DSC02648  !!.jpg'
#  damian_result.csv
# 'Damian Sałkowski - Brighton SEO 2024.gslides'
# 'Damian Sałkowski - Brighton SEO 2024 - Materials.gslides'
#  Damian_Sałkowski_iLoveMarketing_2025_04.pptx
# 'Damian_Sałkowski_iLoveMarketing_2025_04.pptx - Line chart 1.gsheet'
# 'Damian Sałkowski - Prezentacja.pptx - Wykres kołowy 2.gsheet'
# 'Damian Sałkowski - Prezentacja.pptx - Wykres kołowy 5.gsheet'
# 'Damian Sałkowski - Prezentacja.pptx - Wykres kolumnowy 4.gsheet'
# 'Damian Sałkowski - Prezentacja.pptx - Wykres słupkowy 1.gsheet'
# 'Damian Sałkowski_Przedwstępna umowa sprzedaży nieruchomości_28082024 v5.pdf'
# 'Damian Salkowski - SEO Vibes .gslides'
# 'Damian Sałkowski - SEO Vibes WorkShop.gslides'
# 'Damian SaSkowski - Brighton SEO 2024.gslides'
#  Damian-Suplementy.gsheet
# 'Dane Ada.gsheet'
# 'Dane Aplikuj.pl - podobne linki.gsheet'
# 'Dane do automatyzacji.gsheet'
# 'Dane_do_modelu_new (1).csv'
#  Dane_do_modelu_new.csv
# 'Dane do prezki MEC.gsheet'
# 'Dane InPost.gsheet'
# 'Dane - Justyna.gsheet'
# 'Dane_Porównanie narzędzi.gsheet'
# 'Dane raport kategorie.gsheet'
# 'Dane RTB z Senuto.gsheet'
# 'Dane Senuto dla IAI.gsheet'
# 'Dane Senuto & konkurencja - porównanie .gsheet'
#  Dane-Showroom.xlsx
#  dane_sprzedaz_portali_poprawiony_2.csv
# 'Dashboard - zdrowie.gsheet'
#  data-export.csv
# 'Diagram bez tytułu.drawio'
#  dlugosc_opisu_statystyki.csv
# 'Dni od rejestracji do płatności .gsheet'
#  dni_od_rejestracji_do_platnosci_int.csv
# 'Dodatek do książki Eweliny - Intencja użytkownika.gdoc'
# 'Dokument bez tytułu (1).gdoc'
# 'Dokument bez tytułu (2).gdoc'
# 'Dokument bez tytułu (3).gdoc'
# 'Dokument bez tytułu.gdoc'
#  dokumenty-rodo.zip
#  domain_analysis.csv
# 'Domeny AW.gsheet'
# 'Domeny do integracji Senuto.gsheet'
#  Domeny-radius.gsheet
# 'Domeny  SEO.gsheet'
# 'download (27).csv'
# 'Do zaproszenia.gsheet'
#  drive-download-20250215T201722Z-001.zip
# 'Ecommerce AI Writer .gslides'
# 'ecommerce AI Writer - prezentacja sprzedażowa.gslides'
# 'eCommerce Managerowie.gsheet'
# 'Ecommerce tracking .gdoc'
#  ElevenLabs_2024-11-22T14_33_46_Damian_ivc_s100_sb100_se0_b_m2.mp3
# 'Embeddings vs. no embeddings .gsheet'
# 'EN Projekt - Ecommerce AI Writer - prezentacja sprzedażowa.gslides'
# 'Enterprise spadek 2022.gsheet'
#  Error.gsheet
# 'Estymacja efektów SEO SaaS.gsheet'
# 'Estymacje afiliacja.gsheet'
# 'Estymacje dla kampanii SEO dla Landingi.com.gsheet'
#  Explorer_dashboard_for_advance-mk_pl_2023-12-11_export.csv
#  extracted_data_3.csv
# 'extracted_keywords (1).csv'
#  extracted_keywords.csv
#  extracted_kx_parameters.csv
# 'extracted_urls (1).csv'
#  extracted_urls.csv
#  FA_38_07_2024_Wzór_standard.PDF
# 'Faktura_Baza.xlsx - Worksheet.csv'
#  faktury_06112023.xlsx
# 'Faktury Prywatne'
# 'Faktury SensAi'
# 'Faktury Senuto'
# 'Faktury Vestigio.gsheet'
# 'Faktury z systemu - Kasia.gsheet'
#  Fala-Adrenaliny-Plik-Finansowy.gsheet
# 'Festiwal SEO 2021 - Damian Sałkowski.gslides'
# 'Filmy tutoriale - SensAI .gdoc'
#  final_categorization_tree_cleaned.csv
#  final_categorization_tree_utf8.csv
#  final_standard_categorization.csv
#  final_win_percentage_by_category.csv
#  Fine-tuning-obi-poradniki-outline-iteracja-2.gsheet
#  Fine-tuning-OBI-testy
# 'forecast_2024 (1).csv'
# 'forecast_2024 (2).csv'
#  forecast_2025.csv
# 'Free form 1.gsheet'
#  further_cleaned_data.csv
# 'Gantt - Senuto v4.xlsx'
#  Gartner-Senuto.pptx
# 'Globalne relacje.gsheet'
# 'Google Admin Downloads'
# 'Google AI Studio'
#  Google_Autoryzacja.mp4
#  google_pl_stats_domains_13.csv
#  Grafiki
# 'Graf wiedzy - Robert.gsheet'
# 'Grafy wiedzy'
# 'Hackaton - pomysł na produkty .gdoc'
# 'Hackaton - pomysły na rozwiązania.gdoc'
# 'Hackaton - uwagi do strony www.gdoc'
#  Hasła.gdoc
#  Headlines.gsheet
# 'https:  www.senuto.com -Performance-on-Search-2022-12-13 (1).gsheet'
# 'https:  www.senuto.com -Performance-on-Search-2022-12-13.gsheet'
#  IFTTT
#  ILOVEMKT2022_Damian_Sałkowski.key
#  IMG_3603.JPG
#  IMG_3609.JPG
#  IMG_3611.JPG
#  IMG_3615.JPG
#  IMG_3620.JPG
# 'IMG_3622 (1).JPG'
#  IMG_3667.JPG
#  IMG_3669.JPG
#  IMG_3670.JPg
# 'Incentive (1).gsheet'
#  Incentive.gsheet
#  Incentive_plan_obliczenia.gsheet
# 'Incentive - wewnętrzny.gsheet'
# 'Incentive - wewnętrzny last.gsheet'
# 'Informacja pokontrolna.pdf'
#  intent_classified_keywords.csv
#  Invoice-8F73FC37-72940.pdf
#  Inwestycje.gsheet
#  iPad
# 'Jak poczuć się pewnie w tak niepewnym czasie - o syndromie oszusta w SEO.gdoc'
# 'Kalkulacja konferencji - Kalkulator.gsheet'
# 'Kamil (1).gsheet'
#  Kamil.gsheet
# 'Kamil - wynagrodzenie.gsheet'
#  Kamil.xlsx
# 'Kandydaci - Head of SEO.gsheet'
# 'Karol & Damian - Książka - zrzuty ekranu'
# 'Kasia - FV kosztowe.gsheet'
# 'Kategorie (1).gsheet'
#  Kategorie.gsheet
# 'Kategorie IAB.gsheet'
# 'Kategorie - liczba sklepów - 22.01.2021.csv'
# 'Kategorie - test.gsheet'
#  k.debowski@senuto.com
#  keywords_extracted.csv
# 'Keyword Stats 2021-02-17 at 18_11_21.gsheet'
#  Keywords.xlsx
#  klienci_senuto_export.csv
# 'Kohorta - program .gsheet'
# 'Kohorty Senuto.gsheet'
#  Komentatorzy.gsheet
# 'Kontakty do zaproszenia.gsheet'
# 'Kopia NDA - PBN Vestigio.docx'
# 'Kopia pliku Senuto_cc900815-d3fd-4d4a-8d56-57ca2bd8aa2d.gsheet'
# 'Kopia Sales-Performance-Review.gsheet'
# 'Kopia Senuto Budget 2023 (work in progress).gsheet'
# 'Kopia Słupki pionowe.gsheet'
# 'Kopia Tabelka.gsheet'
# 'Kopia Umowa_NDA_Daniel_Jankowski.gdoc'
# 'KoS - Video na prezentacje'
# 'Koszty bezpośrednie i pośrednie październik .gsheet'
# 'Koszty Senuto - benefity i edukacja.gsheet'
# 'Koszty vs. przychody z sales .gsheet'
# 'Krystian - potencjalni pracodawcy.gsheet'
#  Krzysiek_Debowski.JPG
# 'Kulturalnie o SEO - ankieta.gsheet'
# 'Kulturalnie o SEO Sponsorship Contract.gdoc'
# 'Kurs kohortowy oferta.gslides'
# 'KWESTIONARIUSZ OSOBOWY KOMPLET ostateczny.pdf'
# 'Kwiatowadostawa.pl - podsumowanie.gsheet'
# 'Leady - event Wrocław.gsheet'
#  Lenghtvpos.csv
# 'linkedin-chat-send-message (1).csv'
#  linkedin-chat-send-message.csv
# 'LinkedIn do procesowania.gsheet'
#  Linkedin.gsheet
# 'Linki Radek.gsheet'
# 'Linki Vestigio - Radek_Untitled page_Tabela.gsheet'
# 'Linki wewnętrzne - Aplikuj.pl - Raport.gdoc'
# 'Linkowanie wewnętrzne Senuto.gsheet'
#  links_count.csv
# 'Lista projektów.gsheet'
# 'Lista Wrocław.gsheet'
# 'Lista zaakceptowanych kosztów Senuto - bez wynagrodzeń.gsheet'
# 'Lista zaakceptowanych kosztów Senuto.gsheet'
#  Logo
# 'Logo - Alternate Layout - Tussock.png'
#  Lora-AI
# 'Loreal - new meta data.gsheet'
#  losowe_do_kategoryzacji.csv
# 'Maile EDU.gsheet'
# 'Maile Warszawa.gsheet'
# 'Materiał - książka - Damian 2 3.gdoc'
# 'Meblobranie.pl - linkowanie wewnętrzne.gdoc'
# 'Meblobranie.pl - wyniki sasiadow.gsheet'
# 'MEC - 23.01.2025.gslides'
# 'MEC PM.gslides'
# 'MEC PM Kopia.key'
#  Milosz.mp4
#  m.kordowski@senuto.com
#  m.molenda@senuto.com
#  modified_keywords_with_duplicates.csv
#  modified_keywords_with_duplicates_v2.csv
#  Modified_Result_23.csv
# 'Moje kontakty Linkedin.gsheet'
# 'monitoring_cp_plan_keywords (1).csv'
#  monitoring_cp_plan_keywords.csv
# 'monitoring_cp_plans (10).csv'
# 'monitoring_cp_plans (1).csv'
# 'monitoring_cp_plans (2).csv'
# 'monitoring_cp_plans (3).csv'
# 'monitoring_cp_plans (4).csv'
# 'monitoring_cp_plans (5).csv'
# 'monitoring_cp_plans (6).csv'
# 'monitoring_cp_plans (7).csv'
# 'monitoring_cp_plans (8).csv'
# 'monitoring_cp_plans (9).csv'
#  monitoring_cp_plans.csv
# 'monitoring_projects (1).csv'
#  monitoring_projects.csv
# 'monitoring_user_datas (1).csv'
#  monitoring_user_datas_2.csv
# 'monitoring_user_datas_3 (1).csv'
# 'monitoring_user_datas_3 (2).csv'
#  monitoring_user_datas_3.csv
#  monitoring_user_datas.csv
#  monitoring_user_history_products.csv
#  monitoring_user_history_products.txt
# 'monitoring_user_invoices (1).txt'
# 'monitoring_user_invoices_stats (1).csv'
#  monitoring_user_invoices_stats.csv
#  monitoring_user_invoices.txt
#  monitoring_users.csv
#  monitoring_users.txt
# 'Morele.net - Kolejność produktów.gsheet'
# 'Morele.net - Narzędzia 2.gsheet'
#  _MRR_wszystkich_klientów.csv
#  _MRR_wszystkich_klientówpodzial.csv
# 'Nagłówki i pytania.gsheet'
# 'Nagrania z Kulturalnie o SEO.gsheet'
#  NDA_Vestigio.doc
# 'Newsletter SensAI - materiał.gsheet'
# 'Newsy #22.gsheet'
# 'Newsy AI.gsheet'
# 'Newsy SensAI AI Lunch.gsheet'
#  ngrams_1.csv
#  ngrams_2.csv
#  ngrams_3.csv
# 'N-gramy writer Senuto.gsheet'
# 'Nowe Searches.gsheet'
# 'Nowi klienci - struktura zawodów.gsheet'
#  obi.csv
#  obifinetuningporadniki.json
# 'OBI.pl - fine-tuning.gsheet'
# 'OBI.pl - search z sensem .gsheet'
# 'Obi - raport.gsheet'
# 'OBI - wybór tekstu.gdoc'
# 'Odpowiedzi na pytania WhitePress .gdoc'
# 'Oferta Vestigio - Szablon ver. 2.gslides'
# 'Ofertowy 22022025.pdf'
# '[OKR] Q3 Growth - Zarządzenie .gdoc'
# 'Opisy Firm'
#  opisy_firm_Answear_bnie_wewnetrzne_wyniki.csv
# 'opisy_firm_Answear_pnie_wewnetrzne_master (1) (1).csv'
# 'opisy_firm_Answear_pnie_wewnetrzne_master (1).csv'
# 'opisy_firm_Answear_pnie_wewnetrzne_master (2).csv'
# 'opisy_firm_Answear_pnie_wewnetrzne_master (3).csv'
#  opisy_firm_Answear_pnie_wewnetrzne_master.csv
#  opisy_firm_Answear_pzne_widocznosc_senuto.csv
#  opisy_firm_Aplikuj_lnie_wewnetrzne_master.csv
#  opisy_firm_Aplikuj_lnie_wewnetrzne_wyniki.csv
# 'opisy_firm_outgoing_links_2 (1).csv'
#  opisy_firm_outgoing_links_2.csv
#  opisy_firm_outgoing_links_final.csv
# 'orders (2).csv'
# 'orders (4).csv'
# 'orders (5).csv'
#  orders.csv
# 'Oświadczenie Wykonawcy_wzór PB.pdf'
# 'outgoing_links_tables (16).csv'
# 'outgoing_links_tables (8).csv'
# 'outgoing_links_tables (9).csv'
#  Outline.gsheet
#  output_20240813_135601.csv
# 'output_3333 (1).csv'
#  output_33332.csv
#  output_3333.csv
#  output_333.csv
#  output_deduplicated.csv
#  output.docx
#  output.html
#  output_superwnetrze.xlsx
#  output.xlsx
# 'Outreach - proces.gdoc'
# 'Parametry LB.gsheet'
#  partners.csv
# 'PBNy - Gazetki.gsheet'
#  phantombuster-cmo-wrocaw-08122024.csv
#  phantombuster-e-commerce-manager-wrocaw-08122024.csv
#  phantombuster-ecommerce-wrocaw-08122024.csv
#  phantombuster-head-of-marketing-wrocaw-08122024.csv
#  phantombuster-marketing-director-wrocaw-08122024.csv
# 'Pipedrive (Senuto Sp. z o.o)'
# 'Pismo NCBR_odebrane 24.04.2023.pdf'
#  Plan_kurs_SEO_Alior.gdoc
# 'pliki_pdf_z_drive (1).csv'
# 'Pliki remont'
# 'P&L_zapisy_SENUTO_Enterprise.gsheet'
# 'P&L_zapisy_SENUTO.gsheet'
# 'Pobieranie danych o domenach.gsheet'
# '_Pobranie_strony_docelowej (1).csv'
# '_Pobranie_strony_docelowej (2).csv'
#  _Pobranie_strony_docelowej.csv
#  _Pobranie_strony_docelowej.gsheet
# 'Pochodzenie aktywnych klientów.gsheet'
# 'Podkategorie - liczba sklepów - 22.01.2021.csv'
# 'Podsumowanie roku 2021 - Senuto .gdoc'
# 'Podsumowanie roku do kwartalnika Deweloper & Marketing.gdoc'
# 'Podział na mobile i desktop e-commerce.gsheet'
# 'Podział przychodów na kraje (1).gsheet'
# 'Podział przychodów na kraje.gsheet'
#  Pogodynka.gsheet
# 'Porównanie narzędzi Content Editor.gsheet'
# 'Portale Adrian Pakulski.gsheet'
# 'Portale Damian Węglarski.gsheet'
# 'Portale Grzegorz Młyński.gsheet'
# 'Portale Jakub Sergiel.gsheet'
# 'Portale Kamil Kanigowski.gsheet'
# 'Portale Marketing Mind.gsheet'
# 'Portale Michał Kukliński.gsheet'
# 'Portale Michał Mazur.gsheet'
# 'Portale Michał Rochwerger.gsheet'
# 'Portale Paweł Pędzik.gsheet'
# 'Portale Piotr Gabalewicz.gsheet'
# 'Portale SK.csv'
# 'Portale Sławek Chojnacki.gsheet'
# 'Portale Tomasz Jeska.gsheet'
# 'Posty LI - Damian.gsheet'
#  _Powracajcy_klienci.csv
# 'Praca hybrydowa.gdoc'
# 'Practical Application of Language Models for Content Scaling in eCommerce - Emil Tomczynski & Damian Salkowski .gslides'
# 'Prelegenci SEO Rejs.gslides'
# 'Prezentacja bez tytułu (1).gslides'
# 'Prezentacja bez tytułu.gslides'
#  Prezenty.gsheet
# 'Prezenty świąteczne .gsheet'
# 'Prezenty świąteczne.gsheet'
# 'processed_data (1).csv'
#  processed_data.csv
# 'profile-pic (45).png'
# 'profile-pic (47).png'
# 'Profile Wrocław.gsheet'
# 'Program partnerski - Opis .gdoc'
# 'Projekt bez nazwy.gscript'
# 'Projekt B+R Senuto - Prezentacja.gslides'
# 'Promotraffic Experience_1.0.gdoc'
# 'Prompty Dominik.gdoc'
# 'Protokół z kontroli merytorycznej projektu.pdf'
# 'Przepływy cash-flow Senuto do końca 2022.gsheet'
# 'Przychody Senuto dzień po dniu .gsheet'
# 'Przykładowe opisy.gdoc'
# 'Przykładowe opisy produktów.gdoc'
# 'Przykładowy outline AI Writer.gsheet'
# 'Przykładowy raport Senuto_📊 Monitoring_Tabela (1).gsheet'
# 'Przykładowy raport Senuto_📊 Monitoring_Tabela.gsheet'
# 'Pytania do remontu .gdoc'
# 'Pytania na webinary SensAI.gsheet'
# 'Pytania Senuto > WhitePress.gsheet'
# 'Rafał - Wynagrodzenie.gsheet'
# 'RAG - TEST.gdoc'
#  raport.csv
#  Raport_ds.pdf
# 'Raport eCommerce 2021'
# 'Raport eCommerce – listopad 2019 - Wykres kołowy 1.gsheet'
# 'Raport eCommerce – listopad 2019 - Wykres kołowy 2.gsheet'
# 'Raport eCommerce – listopad 2019 - Wykres kołowy 6.gsheet'
# 'Raport eCommerce – listopad 2019 - Wykres kołowy 7.gsheet'
# 'Raport eCommerce – listopad 2019 - Wykres kołowy 8.gsheet'
# 'Raport eCommerce – listopad 2019 - Wykres słupkowy 10.gsheet'
# 'Raport eCommerce – listopad 2019 - Wykres słupkowy 3.gsheet'
# 'Raport eCommerce – listopad 2019 - Wykres słupkowy 4.gsheet'
# 'Raport eCommerce – listopad 2019 - Wykres słupkowy 5.gsheet'
# 'Raport eCommerce – listopad 2019 - Wykres słupkowy 6.gsheet'
# 'Raport eCommerce – listopad 2019 - Wykres słupkowy 9.gsheet'
# 'Raport e-commerce w Polsce 2021 - Bar chart 9.gsheet'
# 'Raport e-commerce w Polsce 2021 - Column chart 14.gsheet'
# 'Raport e-commerce w Polsce 2021 - Column chart 15.gsheet'
# 'Raport e-commerce w Polsce 2021 - Column chart 16.gsheet'
# 'Raport e-commerce w Polsce 2021 - Line chart 17.gsheet'
# 'Raport e-commerce w Polsce 2021 - Line chart 4.gsheet'
# 'Raport e-commerce w Polsce 2021 - Line chart 5.gsheet'
# 'Raport e-commerce w Polsce 2021 - Line chart 6.gsheet'
# 'Raport e-commerce w Polsce 2021 - Line chart 7.gsheet'
# 'Raport e-commerce w Polsce 2021 - Pie chart 12.gsheet'
# 'Raport e-commerce w Polsce 2021 - Pie chart 13.gsheet'
# 'Raport e-commerce w Polsce 2021 - Pie chart 8.gsheet'
# 'Raport e-commerce w Polsce 2021 - Pie chart 9.gsheet'
# 'Raport - wpływ opisów kategorii na widoczność ecommerce.gdoc'
#  raw_location_latitude.csv
#  raw_tracker_steps.csv
# 'Realizacja budżetów - historia .gsheet'
# 'Rekrutacja Full Stack SEO Expert - Vestigio.gsheet'
# 'REMONT ZELWAGI.gsheet'
# 'Remont Zełwągi kosztorys.gsheet'
#  RescueTime
#  RescueTime_Report_Productivity__2021-01-01.gsheet
# 'RescueTime_Report_Productivity__by_day_2021-01-01 (1).csv'
#  RescueTime_Report_Productivity__by_day_2021-02-01.csv
#  RescueTime_Report_Productivity__by_day_2021-03-01.csv
#  RescueTime_Report_Productivity__by_day_2021-04-01.csv
#  RescueTime_Report_Productivity__by_day_2021-05-01.csv
#  RescueTime_Report_Productivity__by_day_2021-06-01.csv
#  RescueTime_Report_Productivity__by_day_2021-07-01.csv
#  RescueTime_Report_Productivity__by_day_2021-08-01.csv
#  RescueTime_Report_Productivity__by_day_2021-09-01.csv
#  RescueTime_Report_Productivity__by_day_2021-10-01.csv
#  RescueTime_Report_Productivity__by_day_2021-11-01.csv
#  RescueTime_Report_Productivity__by_day_2021-12-01.csv
# 'Result_10 (1).csv'
# 'Result_10 (1).gsheet'
# 'Result_10 (2).gsheet'
#  Result_10.csv
#  Result_10.gsheet
#  Result_11.csv
#  Result_120.txt
#  Result_12.txt
# 'Result_13 (1).csv'
# 'Result_13 (2).csv'
# 'Result_13 (3).csv'
#  Result_13.csv
# 'Result_15 (1).csv'
#  Result_15.csv
# 'Result_16 (1).csv'
# 'Result_16 (2).csv'
# 'Result_16 (3).csv'
#  Result_16.csv
# 'result (17).csv'
# 'Result_18 (1).csv'
# 'Result_18 (2).csv'
# 'Result_18 (3).csv'
# 'Result_18 (4).csv'
#  Result_18.csv
# 'result (18).csv'
#  Result_18.gsheet
# 'Result_19 (1).csv'
# 'Result_19 (2).csv'
#  Result_19.csv
# 'result (19).csv'
#  Result_1.csv
#  Result_1.txt
#  Result_20.csv
#  Result_21.csv
# 'result (21).csv'
# 'Result_22 (1).csv'
#  Result_22.csv
# 'Result_23 (1).csv'
#  Result_23.csv
#  Result_23.txt
#  Result_24.csv
# 'Result_28 (1).csv'
# 'Result_28 (2).csv'
#  Result_28.csv
#  Result_2.csv
# 'result (2).csv'
# 'Result_3 (1).csv'
#  Result_31.txt
# 'Result_3 (2).csv'
#  Result_32.txt
# 'Result_33 (1).csv'
#  Result_33.csv
# 'Result_3 (3).csv'
#  Result_33.txt
# 'Result_3 (4).csv'
#  Result_35.csv
# 'Result_3 (5).csv'
#  Result_35.gsheet
#  Result_36.csv
#  Result_36.txt
# 'Result_38 (1).csv'
#  Result_38.csv
#  Result_3.csv
# 'result (3).csv'
#  Result_41.csv
# 'Result_4 (1).csv'
#  Result_42.csv
# 'Result_44 (1).csv'
#  Result_44.csv
#  Result_46.csv
# 'Result_47 (1).csv'
# 'Result_47 (2).csv'
#  Result_47.csv
#  Result_4.csv
# 'Result_50 (1).csv'
#  Result_50.csv
#  Result_51.csv
# 'Result_5 (1).csv'
# 'Result_5 (2).csv'
#  Result_53.csv
#  Result_55.csv
#  Result_57.csv
#  Result_59.csv
#  Result_5.csv
#  Result_60.csv
# 'Result_6 (1).csv'
#  Result_63.txt
#  Result_6.csv
# 'Result_7 (1).csv'
# 'Result_7 (2).csv'
# 'Result_7 (3).csv'
# 'Result_74 (1).csv'
#  Result_74.csv
# 'Result_7 (4).csv'
# 'Result_76 (1).csv'
#  Result_76.csv
#  Result_79.csv
#  Result_7.csv
#  Result_80.csv
#  Result_81.csv
# 'Result_8 (1).csv'
# 'Result_8 (1).gsheet'
#  Result_83.csv
#  Result_87.csv
#  Result_8.csv
#  Result_8.gsheet
# 'Result_9 (1).csv'
# 'Result_9 (1).gsheet'
#  Result_93.csv
#  Result_95.csv
#  Result_99.csv
#  Result_9.csv
#  Result_9.gsheet
# 'Results (1).csv'
# 'results (25).json'
#  results_2_decathlon_blog.csv
# 'results_2_decathlon_pl (1).csv'
# 'Rewolucja no-code - jak automatyzacja zmieni oblicze SEO?.gdoc'
# 'Rezerwacje biletów - Kulturalnie o SEO.gsheet'
# 'RoadMapa - Szybka ścieżka.gsheet'
#  Rodzice.gdoc
# 'Rozliczenie - Fala-Adrenaliny.gsheet'
# 'Rozliczenie Kulturalnie o SEO 2024.gsheet'
# 'Rssy blogów SEO.gsheet'
# 'RTB&Senuto'
# 'Rzeczy do oddania.gsheet'
# 'sample_data_with_predictions_10000 (1).csv'
# 'sample_data_with_predictions_10000 (2).csv'
#  sample_data_with_predictions_10000.csv
# 'sample_data_with_predictions (1).csv'
# 'sample_data_with_predictions_20 (1).csv'
#  sample_data_with_predictions2.csv
#  sample_data_with_predictions3.csv
#  sample_data_with_predictions4.csv
#  sample_data_with_predictions4.gsheet
#  sample_data_with_predictions6.csv
#  sample_data_with_predictions7.csv
#  sample_data_with_predictions8.csv
#  sample_data_with_predictions.csv
#  scaled_pogodynka_data.csv
# 'Scenariusz AI Lunch.gdoc'
# 'ScreenRecording_10-30-2024 13-54-48_1.MP4'
#  screenshot10.png
#  screenshot11.png
#  screenshot12.png
#  screenshot13.png
#  screenshot14.png
#  screenshot15.png
#  screenshot16.png
#  screenshot17.png
#  screenshot18.png
#  screenshot19.png
#  screenshot20.png
#  screenshot21.png
#  screenshot22.png
#  screenshot23.png
#  screenshot24.png
#  screenshot25.png
#  screenshot26.png
#  screenshot27.png
#  screenshot29.png
#  screenshot2.png
#  screenshot30.png
#  screenshot31.png
#  screenshot32.png
#  screenshot33.png
#  screenshot34.png
#  screenshot35.png
#  screenshot36.png
#  screenshot38.png
#  screenshot39.png
#  screenshot3.png
#  screenshot40.png
#  screenshot41.png
# 'screenshot4 (1).png'
#  screenshot42.png
#  screenshot43.png
#  screenshot44.png
#  screenshot45.png
#  screenshot46.png
#  screenshot47.png
#  screenshot48.png
#  screenshot49.png
#  screenshot4.png
#  screenshot50.png
#  screenshot51.png
# 'screenshot5 (1).png'
#  screenshot52.png
#  screenshot53.png
#  screenshot54.png
#  screenshot55.png
#  screenshot56.png
#  screenshot57.png
#  screenshot58.png
#  screenshot59.png
#  screenshot5.png
#  screenshot60.png
#  screenshot61.png
# 'screenshot6 (1).png'
#  screenshot62.png
#  screenshot63.png
#  screenshot64.png
#  screenshot65.png
#  screenshot66.png
#  screenshot67.png
#  screenshot68.png
#  screenshot69.png
#  screenshot6.png
#  screenshot70.png
#  screenshot71.png
# 'screenshot7 (1).png'
#  screenshot72.png
#  screenshot73.png
#  screenshot74.png
#  screenshot75.png
#  screenshot76.png
#  screenshot77.png
#  screenshot78.png
#  screenshot79.png
#  screenshot7.png
#  screenshot80.png
# 'screenshot8 (1).png'
#  screenshot82.png
#  screenshot83.png
#  screenshot85.png
#  screenshot86.png
#  screenshot87.png
#  screenshot89.png
#  screenshot8.png
# 'screenshot9 (1).png'
#  screenshot9.png
# 'Semantic SEO Webinar.gslides'
# 'Semantyczne SEO w 2022.gdoc'
# 'Semstorm - odpowiedzi .gdoc'
# 'Semstorm - propozycja ugody .gdoc'
# 'Senior PHP Developer.gdoc'
# 'SensAI - 7 dniowy kurs mailowy z prompt engineeringu .gdoc'
# 'SensAI - auto newsy.gsheet'
# 'SensAI - fine-tuning.gsheet'
#  SensAI.gsheet
# 'SensAI - Kohorta 2 - cennik.gdoc'
# '[SensAI - kohorta] Crawlowanie LLM.gsheet'
# 'SensAI materiały'
# 'SensAI - Materiały (Damian).gsheet'
# 'SensAi - materiały dodatkowe.gdoc'
# 'SensAI - materiały.gsheet'
# 'SensAI - Prezentacja (kohorta).gslides'
# 'SensAI - Prezentacja (szkolenie stacjonarne).gslides'
# 'SensAI - proces generowania nagłówków.gsheet'
# '[SensAI] Proces Roberta w make.com.gsheet'
# 'SensAI - Senuto.gsheet'
# 'SensAI - testy.gsheet'
# '[Senuto automations] Looker Studio Report .gsheet'
# "Senuto BI 2022_🖤 Black Friday '22 _Tabela.gsheet"
# 'Senuto BI 2022_🔫 Churn rate_Tabela (1).gsheet'
# 'Senuto BI 2022_🔫 Churn rate_Tabela.gsheet'
# 'Senuto BI 2022_🔫 Churn rate_Wykres liniowy.gsheet'
# 'Senuto BI 2022_(Draft) CS metrics tracking_Tabela przestawna.gsheet'
# 'Senuto BI 2022_🌎 Global Domination 👑_Tabela.gsheet'
# 'Senuto BI 2022_👋 Nowi & Aktualni klienci _Tabela (1).gsheet'
# 'Senuto BI 2022_👋 Nowi & Aktualni klienci _Tabela.gsheet'
# 'Senuto BI 2022_👋 Nowi & Aktualni klienci _Wykres liniowy.gsheet'
# 'Senuto BI 2022_💸 Przychody _Bar chart.gsheet'
# 'Senuto BI 2023.gslides'
# 'Senuto BI 2023_💸 Nowy cennik - raport wpływu _Bar chart.gsheet'
# "Senuto BI 2023_🪐 OKR Q3 '23 Tracking File.gsheet"
# 'Senuto BI 2023_💸 Przychody _Line chart.gsheet'
# 'Senuto BI 2023_💸 Przychody _Table.gsheet'
# 'Senuto BI 2023_🤝 WhitePress & Senuto - wymiana leadów (on-boarding)_Bar chart.gsheet'
# 'Senuto BI 2023_🤝 WhitePress & Senuto - wymiana leadów (on-boarding)_Table.gsheet'
# '[Senuto BI] Product team_🤖 AI Writer_Time series.gsheet'
# '[Senuto BI] Product team_📝  Content writer_Table.gsheet'
# 'Senuto Budget 2023.gsheet'
# 'Senuto Budget 2023 (Internal).gsheet'
# 'Senuto Budget 2023 - team template.gsheet'
# 'Senuto deck October 2021 - Wykres kołowy 12.gsheet'
# 'Senuto deck October 2021 - Wykres kolumnowy 2.gsheet'
# 'Senuto - Domeny.docx'
# 'Senuto - Lista klientów.gsheet'
#  Senuto-Logo-Białe.png
#  Senuto-Logo-Czarne.png
#  Senuto-Logo-niebieskie.png
# 'Senuto - plany rozwoju .gdoc'
# 'Senuto - podział płatności rocznych i miesięcznych.gsheet'
# 'Senuto - Prezentacja - Status.gslides'
# 'Senuto & RTB meeting.gslides'
# 'Senuto status.gslides'
# 'Senuto Status Styczeń General.gslides'
# 'Senuto - Strategia rozwoju.gdoc'
# 'Senuto team (1).gsheet'
# 'Senuto team.gsheet'
# 'Senuto V2 - opis i lista nowości.gdoc'
# 'Senuto & WhitePress .gslides'
# 'Senuto - wyjaśnienia dotyczące budżetu .gdoc'
# 'Senuto zaindeksowane strony.gsheet'
# 'Senuto zespół.gsheet'
#  SEOBarcamp.vol1.Damian-Sałkowski.pdf
# 'SEO & Content Camp - prelegent, który dostarczył prezentację ostatni.gsheet'
# 'SEO Glitch 1.gslides'
# 'SEO Glitch 1 - Pie chart 1.gsheet'
# 'SEO - Glitch uczestnicy.gsheet'
# 'SEO na Autopilocie - 9.08 - Damian Sałkowski.gslides'
# 'SEO on autopilot final.gslides'
# 'SEO Raportowanie.gsheet'
# 'SEO Rejs - 3-6.08.2019'
# 'SEO Rejs - kalkulacje .gsheet'
# 'SEO Rejs - Materiały '
# 'SEO Rejs - ukladka (1).mp4'
# 'SEO - Rejs - założenia.gdoc'
# '✅SEO Vibes Cyprus - Damian Sałkowski.pptx'
# 'SEO Vibes - Damian Sałkowski (1).gslides'
# 'SEO Vibes - Damian Sałkowski.gslides'
# 'SEO Vibes Damian Sałkowski.pdf'
# 'SEO Vibes - Damian Sałkowski - "Think, Analyze, Optimize: A Data Head'\''s Way To The Top".gdoc'
# 'SEO w eCommerce – krótka ankieta (Odpowiedzi).gsheet'
# 'Service Summit - data'
#  Serwisy_Szwecja.gsheet
# 'Serwisy - testy.gsheet'
# 'SesnAI - Materiały.gsheet'
#  SIG_0490159631_20241017224934_{c456d08c-7378-7878-7878-887878787878}.pdf
# 'similarity_results (1).csv'
# 'similarity_results (2).csv'
# "Sinsay - Search based targeting - March '23.gsheet"
# 'Site focus badanie.gsheet'
# 'Site focus i radius.gsheet'
#  Sitemapy.gsheet
#  Skategoryzowane_frazy_mistral.csv
# 'SMSy Mati.gsheet'
#  SnIhQ8Q0lF-SRe9I.mp4
# 'Solgar analiza .gsheet'
# 'Solgar.pl - Analiza Klastrów.gsheet'
# 'Spotkania team Senuto & Paweł.gsheet'
#  Sprzedaż
# 'Sprzęt NCBiR.gsheet'
# 'Srednia wartosc płatności rocznych.gsheet'
#  stats_by_category_and_group.csv
#  Status_Ogolny_Senuto_Wrzesien_2019.mp4
# 'Statusy - Senuto.gslides'
# 'Statystyki BSK Senuto.gsheet'
# 'Story about disappointment .gdoc'
# 'Strony kategorii.gsheet'
# 'Supabase Snippet [Answear] Wstępny raport  (1).csv'
# 'Supabase Snippet [Answear] Wstępny raport - best URLs in clusters.csv'
# 'Supabase Snippet [Answear] Wstępny raport - nearest clusters (1).csv'
# 'Supabase Snippet [Answear] Wstępny raport - nearest clusters.csv'
#  Superwnetrze_analiza_aggregated.xlsx
# 'Superwnetrze.pl - analiza.gsheet'
# 'Suplementy diety.gsheet'
#  suplementy_tabela_ponownie.csv
# 'Synergiczni.pl - analiza.gsheet'
# 'System kontroli linków.gsheet'
# 'Szkolenia AI - content.gdoc'
# 'Szkolenie AI - Senuto.gslides'
# 'Szkolenie Senuto dla WhitePress.pptx'
# 'Szybka ścieżka - Senuto - Materiały'
# 'Tarcza antykryzysowa'
# 'Targi e-handlu - Damian Sałkowski.gslides'
#  TechSmith
# 'Teksty do porównania .gdoc'
#  Terranovapolska.pl.gsheet
#  Test.gsheet
# 'Testowanie statusu.gsheet'
#  Toggl_time_entries_2021-01-01_to_2021-12-31.csv
#  Toggl_time_entries_2021-01-01_to_2021-12-31.gsheet
# 'TOP100 US Websites.gsheet'
#  trafficsources-organic.gsheet
# 'Trening Damian .gdoc'
# 'Trenowanie modelu WhitePress.gsheet'
# 'Twitter profile to scrape.gsheet'
# 'Uczestnicy Kulturalnie o SEO 2023.gsheet'
# 'Uczestnicy SEO Rejs.gsheet'
#  ukWydawcy.csv
# 'Umowa B2B wzór.docx'
# 'Umowa Remont Zełwągi.gdoc'
# 'UMOWY Z PRACOWNIKAMI'
# 'Untitled (1).txt'
# 'Untitled document (10).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (17).gdoc'
# 'Untitled document (18).gdoc'
# 'Untitled document (19).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (20).gdoc'
# 'Untitled document (21).gdoc'
# 'Untitled document (22).gdoc'
# 'Untitled document (23).gdoc'
# 'Untitled document (24).gdoc'
# 'Untitled document (25).gdoc'
# 'Untitled document (26).gdoc'
# 'Untitled document (27).gdoc'
# 'Untitled document (28).gdoc'
# 'Untitled document (29).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (30).gdoc'
# 'Untitled document (31).gdoc'
# 'Untitled document (32).gdoc'
# 'Untitled document (33).gdoc'
# 'Untitled document (34).gdoc'
# 'Untitled document (35).gdoc'
# 'Untitled document (36).gdoc'
# 'Untitled document (37).gdoc'
# 'Untitled document (38).gdoc'
# 'Untitled document (39).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (40).gdoc'
# 'Untitled document (41).gdoc'
# 'Untitled document (42).gdoc'
# 'Untitled document (43).gdoc'
# 'Untitled document (44).gdoc'
# 'Untitled document (45).gdoc'
# 'Untitled document (46).gdoc'
# 'Untitled document (47).gdoc'
# 'Untitled document (48).gdoc'
# 'Untitled document (49).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (50).gdoc'
# 'Untitled document (51).gdoc'
# 'Untitled document (52).gdoc'
# 'Untitled document (53).gdoc'
# 'Untitled document (54).gdoc'
# 'Untitled document (55).gdoc'
# 'Untitled document (56).gdoc'
# 'Untitled document (57).gdoc'
# 'Untitled document (58).gdoc'
# 'Untitled document (59).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (60).gdoc'
# 'Untitled document (61).gdoc'
# 'Untitled document (62).gdoc'
# 'Untitled document (63).gdoc'
# 'Untitled document (64).gdoc'
# 'Untitled document (65).gdoc'
# 'Untitled document (66).gdoc'
# 'Untitled document (67).gdoc'
# 'Untitled document (68).gdoc'
# 'Untitled document (69).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (70).gdoc'
# 'Untitled document (71).gdoc'
# 'Untitled document (72).gdoc'
# 'Untitled document (73).gdoc'
# 'Untitled document (74).gdoc'
# 'Untitled document (75).gdoc'
# 'Untitled document (76).gdoc'
# 'Untitled document (77).gdoc'
# 'Untitled document (78).gdoc'
# 'Untitled document (79).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (80).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled Jam.gjam'
# 'Untitled Jam.pdf'
# 'Untitled spreadsheet (100).gsheet'
# 'Untitled spreadsheet (101).gsheet'
# 'Untitled spreadsheet (102).gsheet'
# 'Untitled spreadsheet (103).gsheet'
# 'Untitled spreadsheet (104).gsheet'
# 'Untitled spreadsheet (105).gsheet'
# 'Untitled spreadsheet (106).gsheet'
# 'Untitled spreadsheet (107).gsheet'
# 'Untitled spreadsheet (108).gsheet'
# 'Untitled spreadsheet (109).gsheet'
# 'Untitled spreadsheet (10).gsheet'
# 'Untitled spreadsheet (110).gsheet'
# 'Untitled spreadsheet (111).gsheet'
# 'Untitled spreadsheet (112).gsheet'
# 'Untitled spreadsheet (113).gsheet'
# 'Untitled spreadsheet (114).gsheet'
# 'Untitled spreadsheet (115).gsheet'
# 'Untitled spreadsheet (116).gsheet'
# 'Untitled spreadsheet (117).gsheet'
# 'Untitled spreadsheet (118).gsheet'
# 'Untitled spreadsheet (119).gsheet'
# 'Untitled spreadsheet (11).gsheet'
# 'Untitled spreadsheet (120).gsheet'
# 'Untitled spreadsheet (121).gsheet'
# 'Untitled spreadsheet (122).gsheet'
# 'Untitled spreadsheet (123).gsheet'
# 'Untitled spreadsheet (124).gsheet'
# 'Untitled spreadsheet (125).gsheet'
# 'Untitled spreadsheet (126).gsheet'
# 'Untitled spreadsheet (127).gsheet'
# 'Untitled spreadsheet (128).gsheet'
# 'Untitled spreadsheet (129).gsheet'
# 'Untitled spreadsheet (12).gsheet'
# 'Untitled spreadsheet (130).gsheet'
# 'Untitled spreadsheet (131).gsheet'
# 'Untitled spreadsheet (132).gsheet'
# 'Untitled spreadsheet (133).gsheet'
# 'Untitled spreadsheet (134).gsheet'
# 'Untitled spreadsheet (135).gsheet'
# 'Untitled spreadsheet (136).gsheet'
# 'Untitled spreadsheet (137).gsheet'
# 'Untitled spreadsheet (138).gsheet'
# 'Untitled spreadsheet (139).gsheet'
# 'Untitled spreadsheet (13).gsheet'
# 'Untitled spreadsheet (140).gsheet'
# 'Untitled spreadsheet (141).gsheet'
# 'Untitled spreadsheet (142).gsheet'
# 'Untitled spreadsheet (143).gsheet'
# 'Untitled spreadsheet (144).gsheet'
# 'Untitled spreadsheet (145).gsheet'
# 'Untitled spreadsheet (146).gsheet'
# 'Untitled spreadsheet (147).gsheet'
# 'Untitled spreadsheet (148).gsheet'
# 'Untitled spreadsheet (149).gsheet'
# 'Untitled spreadsheet (14).gsheet'
# 'Untitled spreadsheet (150).gsheet'
# 'Untitled spreadsheet (15).gsheet'
# 'Untitled spreadsheet (16).gsheet'
# 'Untitled spreadsheet (17).gsheet'
# 'Untitled spreadsheet (18).gsheet'
# 'Untitled spreadsheet (19).gsheet'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (20).gsheet'
# 'Untitled spreadsheet (21).gsheet'
# 'Untitled spreadsheet (22).gsheet'
# 'Untitled spreadsheet (23).gsheet'
# 'Untitled spreadsheet (24).gsheet'
# 'Untitled spreadsheet (25).gsheet'
# 'Untitled spreadsheet (26).gsheet'
# 'Untitled spreadsheet (27).gsheet'
# 'Untitled spreadsheet (28).gsheet'
# 'Untitled spreadsheet (29).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (30).gsheet'
# 'Untitled spreadsheet (31).gsheet'
# 'Untitled spreadsheet (32).gsheet'
# 'Untitled spreadsheet (33).gsheet'
# 'Untitled spreadsheet (34).gsheet'
# 'Untitled spreadsheet (35).gsheet'
# 'Untitled spreadsheet (36).gsheet'
# 'Untitled spreadsheet (37).gsheet'
# 'Untitled spreadsheet (38).gsheet'
# 'Untitled spreadsheet (39).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet (40).gsheet'
# 'Untitled spreadsheet (41).gsheet'
# 'Untitled spreadsheet (42).gsheet'
# 'Untitled spreadsheet (43).gsheet'
# 'Untitled spreadsheet (44).gsheet'
# 'Untitled spreadsheet (45).gsheet'
# 'Untitled spreadsheet (46).gsheet'
# 'Untitled spreadsheet (47).gsheet'
# 'Untitled spreadsheet (48).gsheet'
# 'Untitled spreadsheet (49).gsheet'
# 'Untitled spreadsheet (4).gsheet'
# 'Untitled spreadsheet (50).gsheet'
# 'Untitled spreadsheet (51).gsheet'
# 'Untitled spreadsheet (52).gsheet'
# 'Untitled spreadsheet (53).gsheet'
# 'Untitled spreadsheet (54).gsheet'
# 'Untitled spreadsheet (55).gsheet'
# 'Untitled spreadsheet (56).gsheet'
# 'Untitled spreadsheet (57).gsheet'
# 'Untitled spreadsheet (58).gsheet'
# 'Untitled spreadsheet (59).gsheet'
# 'Untitled spreadsheet (5).gsheet'
# 'Untitled spreadsheet (60).gsheet'
# 'Untitled spreadsheet (61).gsheet'
# 'Untitled spreadsheet (62).gsheet'
# 'Untitled spreadsheet (63).gsheet'
# 'Untitled spreadsheet (64).gsheet'
# 'Untitled spreadsheet (65).gsheet'
# 'Untitled spreadsheet (66).gsheet'
# 'Untitled spreadsheet (67).gsheet'
# 'Untitled spreadsheet (68).gsheet'
# 'Untitled spreadsheet (69).gsheet'
# 'Untitled spreadsheet (6).gsheet'
# 'Untitled spreadsheet (70).gsheet'
# 'Untitled spreadsheet (71).gsheet'
# 'Untitled spreadsheet (72).gsheet'
# 'Untitled spreadsheet (73).gsheet'
# 'Untitled spreadsheet (74).gsheet'
# 'Untitled spreadsheet (75).gsheet'
# 'Untitled spreadsheet (76).gsheet'
# 'Untitled spreadsheet (77).gsheet'
# 'Untitled spreadsheet (78).gsheet'
# 'Untitled spreadsheet (79).gsheet'
# 'Untitled spreadsheet (7).gsheet'
# 'Untitled spreadsheet (80).gsheet'
# 'Untitled spreadsheet (81).gsheet'
# 'Untitled spreadsheet (82).gsheet'
# 'Untitled spreadsheet (83).gsheet'
# 'Untitled spreadsheet (84).gsheet'
# 'Untitled spreadsheet (85).gsheet'
# 'Untitled spreadsheet (86).gsheet'
# 'Untitled spreadsheet (87).gsheet'
# 'Untitled spreadsheet (88).gsheet'
# 'Untitled spreadsheet (89).gsheet'
# 'Untitled spreadsheet (8).gsheet'
# 'Untitled spreadsheet (90).gsheet'
# 'Untitled spreadsheet (91).gsheet'
# 'Untitled spreadsheet (92).gsheet'
# 'Untitled spreadsheet (93).gsheet'
# 'Untitled spreadsheet (94).gsheet'
# 'Untitled spreadsheet (95).gsheet'
# 'Untitled spreadsheet (96).gsheet'
# 'Untitled spreadsheet (97).gsheet'
# 'Untitled spreadsheet (98).gsheet'
# 'Untitled spreadsheet (99).gsheet'
# 'Untitled spreadsheet (9).gsheet'
# 'Untitled spreadsheet.gsheet'
#  URLs.gsheet
#  urls_updated2.csv
#  urls_updated2.json
#  urls_updated3.json
#  urls_updated5.json
#  urls_updated.json
# 'Uzupełnienia do tekstu semantyczne SEO, wersji ENG.gdoc'
#  verticals.csv
# 'Vestigio Invoices.gsheet'
# 'Vestigio - metryki HR.gslides'
#  v.umanska@senuto.com
# 'Wakacje 2024.gsheet'
# 'Warszawskie agencje - WhitePress.gsheet'
# '"Wbijanie" się w content GAP serwisu przy publikacji artykułu.gdoc'
# 'Webinar - 15.11.22 - Damian Sałkowski.gslides'
# 'Webinar - Semantyczne SEO - 26.07 - Damian Sałkowski.gslides'
# 'Webinar Senuto & WhitePress - 12.06.2024.gslides'
# 'Webinar SEO Masterclass 3.0 - AI Overview w Polsce - Damian Sałkowski .gslides'
# 'WebVitals brakujace.csv'
#  Weight_Data.csv
#  Weight_Data.gsheet
#  Weight_Data.xls
# 'Welcome discount.gsheet'
# 'WELLTORY_MEASUREMENT_DATA_EXPORT_04 Feb 2021, 12_00 AM-04 Feb 2021, 12_00 AM.csv'
#  wfirma.pl
# 'WhitePress - Dane do zakupu serwisów.gsheet'
#  WhitePress.gsheet
# 'WhitePress - nowe możliwości AI .gdoc'
# 'WhitePress - przeczyszczona baza.gsheet'
# 'WhitePress & Senuto .gdoc'
# 'WhitePress - usługa PBN.gslides'
#  whitepress_wordpresses.csv
#  winners_losers_table.csv
#  WIZUALIZACJE-20250208T093334Z-001.zip
# 'Writer 1.5 - Materiały dla marketingu.gdoc'
# 'Writer 2.0'
# 'Writer - prompty .gdoc'
# 'Writer prompty Senuto'
# 'Wszystko czego nauczysz się na SensAI.gdoc'
#  Wtyczka_AI_Overview
#  Wyczyszczone_kategorie_oczyszczone.csv
#  Wydatki.gsheet
# 'Wyjazd Bielsko .gsheet'
# 'wykaz wydatków 1.03.2023.xlsx'
# 'Wykres konkurencji monitoring.gsheet'
# 'wyniki (1).csv'
# 'wyniki (2).csv'
# 'wyniki (3).csv'
# 'wyniki (4).csv'
# 'wyniki (5).csv'
#  wyniki.csv
# 'wyniki_sasiadow (1).csv'
# 'wyniki_sasiadow (2).csv'
#  wyniki_sasiadow.csv
# 'WZORY UMÓW Z KLIENTAMI'
# 'Zacznij wyszukiwanie (1).gsheet'
# 'Zacznij wyszukiwanie.gsheet'
# 'Zagraniczni influencerzy - relacje.gsheet'
# 'Załącznik 2.gsheet'
# 'Załącznik nr 1 do Spraw B+R_sent.xlsx'
# 'Załącznik nr 2 do projektu B+R (1).xls'
# 'Zamówienia biletów - SEO Rejs.gsheet'
# 'Zapisy na SEO Vibes 2025 dla społeczności SensAI.gsheet'
# 'Zaproszenie event.gsheet'
#  _Zapytanie_do_wycigcia_powyszych_danych.csv
#  Zesp_Senuto_Zesp_1641205619.xlsx
#  Zesp_Senuto_Zesp_1674554201.gsheet
#  Zesp_Senuto_Zesp_1674554201.xlsx
#  _Zmiana_MRR_starych_klientów.csv
# 'Zmiany w wynagrodzeniach Senuto.gsheet'
# 'Znacznik dat.gsheet'

# %% [markdown]
# # 📥 Pobieranie danych z publicznego GitHub
#
# **TL;DR** — skopiuj link **Raw**, użyj `wget`, a potem `unzip`.
#
# ## 1 ➡️ Link *Raw* vs. link z interfejsem
#
# | ❌ **Nie do pobierania** | ✔️ **Do pobierania (Raw)** |
# |--------------------------|----------------------------|
# | `https://github.com/salek7/seo3.0/blob/main/Datasety/processed_keywords.zip` | `https://raw.githubusercontent.com/salek7/seo3.0/main/Datasety/processed_keywords.zip` |
#
# ## 2 ➡️ Pobranie i rozpakowanie w Colab
#
# ```python
# !wget https://raw.githubusercontent.com/salek7/seo3.0/main/Datasety/processed_keywords.zip
# !unzip processed_keywords.zip
# ```
#
# 🔒 Dostęp do prywatnego repozytorium
# Do klonowania prywatnych repozytoriów potrzebny jest Personal Access Token (PAT).
#
# Krok 1 — Generowanie PAT na GitHub
#
# GitHub → Settings ▸ Developer settings ▸ Personal access tokens (classic)
# Generate new token (classic)
# Ustaw:
#
# Note: colab-access
# Expiration: np. 30 dni
# Scopes: zaznacz repo
#
# Kliknij Generate token i skopiuj go w bezpieczne miejsce.
#
# ⚠️ Token jest wyświetlany tylko raz. W razie zgubienia wygeneruj nowy.
#
# Krok 2 — Bezpieczne użycie tokenu w Colab (sekrety)
# Dodanie sekretu w Colab
#
# W Colab kliknij ikonę 🔑 Secrets po lewej.
# + Add a new secret
#
# Name: GITHUB_TOKEN
# Value: tu wklej swój PAT
#
# Klonowanie repozytorium
# python# Pobranie tokenu z sekretem
# from google.colab import userdata
# github_token = userdata.get('GITHUB_TOKEN')
#
# Dane repozytorium
# username = "twoj_user"
# repo     = "twoje_prywatne_repo"
#
# URL z tokenem
# repo_url = f"https://{github_token}@github.com/{username}/{repo}.git"
#
# Klonowanie (pobieramy tylko ostatni commit)
# !git clone --depth 1 {repo_url}
#
# Podgląd zawartości
# %cd {repo}
# !ls -al
# %cd ..
#
# 💡 Tip: zamiast sekretów możesz użyć zmiennej środowiskowej lub pliku .git-credentials, ale sekrety Colab są najwygodniejsze i najbezpieczniejsze.

# %%
# !wget https://github.com/openimages/dataset/blob/main/dict.csv
# Out:
# --2025-04-30 10:44:24--  https://github.com/openimages/dataset/blob/main/dict.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dict.csv’
#
# dict.csv                [ <=>                ] 426.46K  --.-KB/s    in 0.07s
#
# 2025-04-30 10:44:24 (6.40 MB/s) - ‘dict.csv’ saved [436694]

# %% [markdown]
# ## Praca Zespołowa i Raportowanie w SEO 3.0: Współpraca w Colab
#
# Colab to nie tylko narzędzie dla samotnych wilków SEO. Ułatwia współpracę:
# *   **Udostępnianie:** Kliknij przycisk **"Udostępnij"** (prawy górny róg), aby podzielić się notatnikiem z kolegami z zespołu SensAI, przełożonym lub nawet klientem.
# *   **Uprawnienia:** Kontroluj, kto może tylko oglądać, kto komentować, a kto edytować Twój skrypt czy analizę.
# *   **Wspólna Edycja:** Pracujcie nad jednym audytem lub skryptem w tym samym czasie. Idealne do szybkiego rozwiązywania problemów i dzielenia się wiedzą.

# %% [markdown]
# # Podsumowanie: Twój Nowy Niezbędnik w SEO 3.0
#
# Gratulacje! Opanowałeś/aś podstawy Google Colab – narzędzia, które w SensAI uważamy za kluczowe dla nowoczesnego specjalisty SEO. Potrafisz już:
# *   Tworzyć i edytować komórki tekstowe (Markdown) do dokumentacji i kodu (Python) do automatyzacji.
# *   Uruchamiać skrypty i interpretować ich wyniki.
# *   Przechowywać dane SEO w zmiennych.
# *   Importować i instalować (`!pip`) biblioteki Python niezbędne w SEO.
# *   Rozumieć znaczenie Runtime i akceleratorów (GPU/TPU) dla zaawansowanych analiz.
# *   Montować Dysk Google, aby pracować ze swoimi plikami i danymi SEO.
# *   Współpracować i udostępniać swoje prace.
#
# **Pamiętaj o ograniczeniach darmowej wersji:** limitowany czas sesji, zmienna dostępność zasobów, konieczność ponownej instalacji bibliotek po restarcie.
#
# **Co Dalej w Kursie SensAI?**
# Teraz, gdy znasz podstawy Colab, będziemy go używać do praktycznych zadań SEO 3.0:
# *   Pobieranie danych z **Google Search Console API**.
# *   Prosty **web scraping** do analizy konkurencji.
# *   **Analiza i wizualizacja danych** słów kluczowych za pomocą `pandas` i `matplotlib`.
# *   **Automatyzacja** małych, powtarzalnych zadań.
# *   Pierwsze kroki w **NLP** (przetwarzaniu języka naturalnego) do analizy treści.
#
# Przygotuj się na skok w przyszłość SEO! Colab będzie Twoim kokpitem.
